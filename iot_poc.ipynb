# %% [markdown]
# <a href="https://colab.research.google.com/github/gradoj/iot_poc/blob/main/iot_poc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Helium Iot Poc Oracle data
#
# This data comes from the iot oracle data which contains protobuf info split into messages as described https://docs.helium.com/oracles/oracle-data and saved as partitioned parquet files stored in an s3 bucket.
#
# The data has been broken up into send and received beacons partitioned across the variable `date` allowing processing of only the files required. To keep the files a manageable size the received beacons have also been partioned by hour.
# ```
# sent_beacons.parquet
# |
# ├───date=2023-05-16
# │       4a8554c5f1d849ceb177a27c91329a6f-0.parquet
# │
# ├───date=2023-05-17
# │       308fa6a011714a46bfc5d08d7f54c19f-0.parquet
# │       4a8554c5f1d849ceb177a27c91329a6f-0.parquet
#
#
# rx_beacons_hourly.parquet
# |
# ├───date=2023-01-27
# │   ├───hour=0
# │   │       9edefc8181f740778aa2fcfa5a549bba-0.parquet
# │   │
# │   ├───hour=1
# │   │       9edefc8181f740778aa2fcfa5a549bba-0.parquet
# ```

# %% [markdown]
# # Exploring the schema
# Since the dataset it too large to fit in entirely in memory or maybe even on your local machine at all it will be accessed directly from the bucket. There are multiple options like pyarrow, dask, pandas, etc but duckdb will be the focus here https://duckdb.org/ as it support s3 buckets, geospatial and h3 extentions it appears a very good match for this dataset.

# %% [markdown]
# ## Installation
#
# Install the packages required and map google drive for convenience.

# %%
# !pip install --quiet duckdb
# !pip install --quiet duckdb-engine
# !pip install --quiet pandas
# !pip install --quiet matplotlib
# !pip install --quiet colab-env --upgrade
# !pip install --quiet s3fs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.2/268.2 kB 30.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 85.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for colab-env (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 22.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 79.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 43.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.3 MB/s eta 0:00:00

# %%
# map to google drive to retrieve secret credentials or store output files like csv 
from google.colab import drive
drive.mount('/gdrive')#, force_remount=True)

import colab_env
# Out:
# Mounted at /gdrive
# Mounted at /content/gdrive

# %% [markdown]
# ## Make duckdb connection to bucket
# Install httpfs and setup the variables needed in duckdb to access the bucket.

# %%
import os
import duckdb

db = duckdb.connect() # No need to pass a file name, we will use a VIEW

query = """
INSTALL httpfs;
LOAD httpfs;
SET s3_endpoint='{s3_endpoint}';
SET s3_access_key_id='{s3_access_key_id}';
SET s3_secret_access_key='{s3_secret_access_key}';
""".format(s3_endpoint = os.getenv("s3_endpoint"),s3_access_key_id=os.getenv("s3_access_key_id"),s3_secret_access_key=os.getenv("s3_secret_access_key"))

# %time db.execute(query)
# Out:
# CPU times: user 210 ms, sys: 0 ns, total: 210 ms
# Wall time: 218 ms

# %% [markdown]
# ## Query the Parquet files schema using DESCRIBE
# Since the data is partition by date the best method is to open the dataset using wildcards as shown below. The `hive_partioning=1` tells duckdb to process the directories as a data column.

# %%
# %time rxbeacon_count = db.execute("DESCRIBE SELECT * FROM read_parquet('s3://iotpoc/sent_beacons.parquet/**/*.parquet', hive_partitioning=1)").df()

#%time txbeacon_count = db.execute("SELECT COUNT(*),MIN(date) as firstTime,MAX(date) as lastTime \
#                                  FROM read_parquet('s3://iotpoc/sent_beacons.parquet/**/*.parquet', hive_partitioning=1) \
#                                  WHERE (date = '2023-02-23' )").df()
display(rxbeacon_count)
# Out:
# CPU times: user 216 ms, sys: 18.1 ms, total: 235 ms
# Wall time: 1.58 s
#           column_name column_type null  key default extra
# 0               pocId     VARCHAR  YES  NaN     NaN   NaN
# 1   receivedTimestamp   TIMESTAMP  YES  NaN     NaN   NaN
# 2            location      BIGINT  YES  NaN     NaN   NaN
# 3                 lat       FLOAT  YES  NaN     NaN   NaN
# 4                 lon       FLOAT  YES  NaN     NaN   NaN
# 5            hexScale      BIGINT  YES  NaN     NaN   NaN
# 6          rewardUnit      BIGINT  YES  NaN     NaN   NaN
# 7              pubKey     VARCHAR  YES  NaN     NaN   NaN
# 8           frequency     UBIGINT  YES  NaN     NaN   NaN
# 9            datarate     VARCHAR  YES  NaN     NaN   NaN
# 10            txPower     INTEGER  YES  NaN     NaN   NaN
# 11          timestamp     UBIGINT  YES  NaN     NaN   NaN
# 12            channel     INTEGER  YES  NaN     NaN   NaN
# 13               tmst      BIGINT  YES  NaN     NaN   NaN
# 14          elevation     INTEGER  YES  NaN     NaN   NaN
# 15               gain     INTEGER  YES  NaN     NaN   NaN
# 16               date     VARCHAR  YES  NaN     NaN   NaN

# %% [markdown]
# ## SUMMARIZE

# %%
# %time txbeacon_count = db.execute("SUMMARIZE SELECT * \
                                   FROM read_parquet('s3://iotpoc/sent_beacons.parquet/**/*.parquet', hive_partitioning=1) \
                                   WHERE (date = '2023-02-23' ) ").df()

display(txbeacon_count)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='100%'), style=ProgressStyle(bar_color='black'))
# CPU times: user 4.86 s, sys: 66.8 ms, total: 4.92 s
# Wall time: 11.8 s
#           column_name column_type  \
# 0               pocId     VARCHAR
# 1   receivedTimestamp   TIMESTAMP
# 2            location      BIGINT
# 3                 lat       FLOAT
# 4                 lon       FLOAT
# 5            hexScale      BIGINT
# 6          rewardUnit      BIGINT
# 7              pubKey     VARCHAR
# 8           frequency     UBIGINT
# 9            datarate     VARCHAR
# 10            txPower     INTEGER
# 11          timestamp     UBIGINT
# 12            channel     INTEGER
# 13               tmst      BIGINT
# 14          elevation     INTEGER
# 15               gain     INTEGER
# 16               date     VARCHAR
#
#                                              min  \
# 0   +++OJCLW/KYELlwYk1Rf66R9jAx97xPTQJ9DzE27M9A=
# 1                        2023-02-23 07:00:00.023
# 2                             630524015154703359
# 3                                     -46.434513
# 4                                     -170.66478
# 5                                              3
# 6                                              0
# 7   AA++5L+F0qRox1uyhm8zZ+dv4tTeEenB9QUZlT1Onafw
# 8                                      486300000
# 9                                      SF12BW125
# 10                                             0
# 11                                 1677135600023
# 12                                             0
# 13                                             0
# 14                                             0
# 15                                             0
# 16                                    2023-02-23
#
#                                              max approx_unique  \
# 0   zzzf9fb+pgzF8hLk67RbUWLIblAPwLbel1weB29qBuk=       1227805
# 1                        2023-02-24 06:59:59.961       1210587
# 2                             634351374012531199        401633
# 3                                      70.377785        377147
# 4                                      178.03728        400833
# 5                                          10000          7659
# 6                                          18926            15
# 7   APzzv8fWOcK8JHGzWd+xoZtXc1lLRUtJMJR5Nun/BL9e        398252
# 8                                      924600000            67
# 9                                       SF9BW125             3
# 10                                            36            37
# 11                                 1677221999961       1223227
# 12                                             0             1
# 13                                    4294967295         13469
# 14                                             0             1
# 15                                             0             1
# 16                                    2023-02-23             1
#
#                       avg                 std                 q25  \
# 0                     NaN                 NaN                 NaN
# 1                     NaN                 NaN                 NaN
# 2   6.313013912606953e+17  475286752107816.44  631049323544694656
# 3       39.93165830466295  14.440351631856393  35.723223173891824
# 4      -36.94049656593446   63.93491282166989  -89.46784605653907
# 5      6894.1837141380765   3114.068375596404                4323
# 6      14363.843339752855  6603.2086835687915               10772
# 7                     NaN                 NaN                 NaN
# 8       886854397.7405648  31268003.392004333   867899976.7547817
# 9                     NaN                 NaN                 NaN
# 10        19.550795776175   8.233554204728728                  12
# 11     1677178578317.6162  25775807.591659363  1677154123564.4897
# 12                    0.0                 0.0                   0
# 13     22636134.754086096  252255005.60706252                   0
# 14                    0.0                 0.0                   0
# 15                    0.0                 0.0                   0
# 16                    NaN                 NaN                 NaN
#
#                    q50                 q75    count null_percentage
# 0                  NaN                 NaN  1240487            0.0%
# 1                  NaN                 NaN  1240487            0.0%
# 2   631212067708249984  631279194750569856  1240487            0.0%
# 3   41.621620236314236  48.777144602977806  1240487            0.0%
# 4   -44.39574252817715  11.767249101230561  1240487            0.0%
# 5                 7491               10000  1240487            0.0%
# 6                18658               18926  1240487            0.0%
# 7                  NaN                 NaN  1240487            0.0%
# 8          903900000.0         904700000.0  1240487            0.0%
# 9                  NaN                 NaN  1240487            0.0%
# 10                  23                  27  1240487            0.0%
# 11   1677178463499.043    1677201060034.06  1240487            0.0%
# 12                   0                   0  1240487            0.0%
# 13                   0                   0  1240487            0.0%
# 14                   0                   0  1240487            0.0%
# 15                   0                   0  1240487            0.0%
# 16                 NaN                 NaN  1240487            0.0%

# %%
# %time rxbeacon_count = db.execute("SUMMARIZE SELECT * \
                                   FROM read_parquet('s3://iotpoc/rx_beacons_hourly.parquet/**/*.parquet', hive_partitioning=1) \
                                   WHERE (date = '2023-02-23' ) \
                                   AND (hour = 0) ").df()

display(rxbeacon_count)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='100%'), style=ProgressStyle(bar_color='black'))
# CPU times: user 16.2 s, sys: 225 ms, total: 16.4 s
# Wall time: 30.5 s
#           column_name column_type  \
# 0               pocId     VARCHAR
# 1   receivedTimestamp   TIMESTAMP
# 2            location      BIGINT
# 3                 lat       FLOAT
# 4                 lon       FLOAT
# 5            hexScale      BIGINT
# 6          rewardUnit      BIGINT
# 7              pubKey     VARCHAR
# 8           frequency     UBIGINT
# 9            datarate     VARCHAR
# 10             signal     INTEGER
# 11                snr     INTEGER
# 12          timestamp     UBIGINT
# 13               tmst      BIGINT
# 14          elevation     INTEGER
# 15               gain     INTEGER
# 16             status     VARCHAR
# 17      invalidReason     VARCHAR
# 18    participantSide     VARCHAR
# 19           selected     TINYINT
# 20               date     VARCHAR
# 21               hour     VARCHAR
#
#                                              min  \
# 0   +++j3tc7O43KI41Ov1YzMHBTtyOYYGVBPqWzbjgnSVY=
# 1                          2023-02-23 07:00:00.5
# 2                                              0
# 3                                     -45.853218
# 4                                     -159.38126
# 5                                              0
# 6                                              0
# 7   AA++3jev7QqHuANS7uAXMX/TEAA4gTf3nNYvWDWZoak3
# 8                                      486300000
# 9                                      SF12BW125
# 10                                         -2420
# 11                                          -280
# 12                               657860931000275
# 13                                             0
# 14                                             0
# 15                                             0
# 16                                       invalid
# 17                                      bad_rssi
# 18                                     side_none
# 19                                             0
# 20                                    2023-02-23
# 21                                             0
#
#                                              max approx_unique  \
# 0   zzy5o8guv39l/+n7/YfWCeWhV7RCktoNs2kcON7joOY=         53463
# 1                        2023-02-23 08:09:39.651       2357688
# 2                             634351374005476863        320145
# 3                                       70.06249        304777
# 4                                      178.02933        316570
# 5                                          10000          5611
# 6                                          10000            12
# 7   AeOyyBYc9wJh667S9OkUdqKUFKU3EqV6NziO4dUyUakm        326226
# 8                                      975099968           117
# 9                                       SF9BW125             3
# 10                                          1190           196
# 11                                           199           443
# 12                           1804138904522176215       4334756
# 13                                    4294965327       4385556
# 14                                             0             1
# 15                                             0             1
# 16                                         valid             2
# 17                                   reason_none             8
# 18                                       witness             2
# 19                                             1             2
# 20                                    2023-02-23             1
# 21                                             0             1
#
#                        avg                     std                     q25  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2    5.585859741487421e+17  2.0143279229619296e+17      631033957656707712
# 3        37.60852354202554      16.276953873819217        35.8468484808033
# 4      -12.343681253039708       53.04109005481873      -9.185695100794069
# 5        5575.792431830578      3685.1687561513263                    2104
# 6        362.2360176034205      1150.4087740456664                       0
# 7                      NaN                     NaN                     NaN
# 8        877245888.1674485      17395988.385984655             867500032.0
# 9                      NaN                     NaN                     NaN
# 10     -1164.1823058420346       152.4457071178924                   -1270
# 11      -67.46020206246874       87.53231488921064                    -137
# 12  1.6771242609799813e+18      1482896230725970.5  1.6771364389064297e+18
# 13      2102038185.0921094       1267871590.967178               994183010
# 14                     0.0                     0.0                       0
# 15                     0.0                     0.0                       0
# 16                     NaN                     NaN                     NaN
# 17                     NaN                     NaN                     NaN
# 18                     NaN                     NaN                     NaN
# 19      0.1288001377328931     0.33497863753638685                       0
# 20                     NaN                     NaN                     NaN
# 21                     NaN                     NaN                     NaN
#
#                        q50                     q75    count null_percentage
# 0                      NaN                     NaN  4425958            0.0%
# 1                      NaN                     NaN  4425958            0.0%
# 2       631059910279689728      631278196455299712  4425958            0.0%
# 3         41.4652450563109       48.04991452025459  4425958            0.0%
# 4        4.862861558840258       24.61303885958575  4425958            0.0%
# 5                     5881                    9704  4425958            0.0%
# 6                        0                       0  4425958            0.0%
# 7                      NaN                     NaN  4425958            0.0%
# 8        868099964.0704175       896424356.8965634  4425958            0.0%
# 9                      NaN                     NaN  4425958            0.0%
# 10                   -1180                   -1087  4425958            0.0%
# 11                     -73                       3  4425958            0.0%
# 12  1.6771374490524654e+18  1.6771382941042025e+18  4425958            0.0%
# 13              2109082387              3179943321  4425958            0.0%
# 14                       0                       0  4425958            0.0%
# 15                       0                       0  4425958            0.0%
# 16                     NaN                     NaN  4425958            0.0%
# 17                     NaN                     NaN  4425958            0.0%
# 18                     NaN                     NaN  4425958            0.0%
# 19                       0                       0  4425958            0.0%
# 20                     NaN                     NaN  4425958            0.0%
# 21                     NaN                     NaN  4425958            0.0%

# %% [markdown]
# # Accessing the data

# %%
# %time rxbeacon_count = db.execute("SELECT * \
                                   FROM read_parquet('s3://iotpoc/rx_beacons_hourly.parquet/**/*.parquet', hive_partitioning=1) \
                                   WHERE (date = '2023-03-23' ) \
                                   AND (hour = 0) \
                                   LIMIT 2").df()

display(rxbeacon_count)
# Out:
# CPU times: user 96.2 ms, sys: 16 ms, total: 112 ms
# Wall time: 5.85 s
#                                           pocId       receivedTimestamp  \
# 0  5WREMalstBKW+cU0qTeeKdrWdCpW5koX9q8zNj+Fl0Q= 2023-03-23 06:00:03.793
# 1  5WREMalstBKW+cU0qTeeKdrWdCpW5koX9q8zNj+Fl0Q= 2023-03-23 06:00:03.807
#
#              location        lat       lon  hexScale  rewardUnit  \
# 0  630950130547433983  53.164478 -2.197567     10000        2918
# 1  630950126756440063  53.073185 -2.191010     10000        2918
#
#                                          pubKey  frequency   datarate  ...  \
# 0  AIXXZXnm7A+1L2wLBwpZyRgqL8OZRUingMhZFMKOnwR2  867700032  SF12BW125  ...
# 1  APBIdLGvO4JtKO30K5DdRrzQPePvjYXpiParqILJHQbo  867700032  SF12BW125  ...
#
#              timestamp        tmst  elevation  gain  status  invalidReason  \
# 0  1679551203467954308  2013472588          0     0   valid    reason_none
# 1  1679551203454019885  1651927641          0     0   valid    reason_none
#
#   participantSide selected        date  hour
# 0       side_none        1  2023-03-23     0
# 1       side_none        1  2023-03-23     0
#
# [2 rows x 22 columns]
